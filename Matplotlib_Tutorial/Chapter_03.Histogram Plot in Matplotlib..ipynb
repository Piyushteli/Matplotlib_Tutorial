# %% [markdown]
# # Histogram Plot.

# %%
import matplotlib.pyplot as plt
import numpy as np 
import random


x=np.random.randint(10,60,(50))
print(x)
# Out:
# [51 21 24 35 37 14 47 22 57 52 36 36 55 48 19 57 18 27 40 24 30 14 51 55
#  37 23 50 33 36 14 38 59 33 53 38 34 21 56 59 43 36 22 36 38 43 19 34 56
#  17 34]

# %%
no=[51,21,24,35,37,14,47,22,57,52,36,36,55,48,19,57,18,27,40,24,30,14,51,55
 ,37,23,50,33,36,14,38,59,33,53,38,34,21,56,59,43,36,22,36,38,43,19,34,56,
 17,34]

l=[10,20,30,40,50,60]
plt.hist(no,color="b",edgecolor="r",cumulative=-1)
plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("no")
plt.show()

# %%
no=[51,21,24,35,37,14,47,22,57,52,36,36,55,48,19,57,18,27,40,24,30,14,51,55
 ,37,23,50,33,36,14,38,59,33,53,38,34,21,56,59,43,36,22,36,38,43,19,34,56,
 17,34]

l=[10,20,30,40,50,60]
plt.hist(no,color="b",edgecolor="r",bottom=10)
plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("no")
plt.show()

# %%
no=[51,21,24,35,37,14,47,22,57,52,36,36,55,48,19,57,18,27,40,24,30,14,51,55
 ,37,23,50,33,36,14,38,59,33,53,38,34,21,56,59,43,36,22,36,38,43,19,34,56,
 17,34]

l=[10,20,30,40,50,60]
plt.hist(no,"auto",(0,100),edgecolor="r")
plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("no")
plt.show()

# %%
no=[51,21,24,35,37,14,47,22,57,52,36,36,55,48,19,57,18,27,40,24,30,14,51,55
 ,37,23,50,33,36,14,38,59,33,53,38,34,21,56,59,43,36,22,36,38,43,19,34,56,
 17,34]

l=[10,20,30,40,50,60]
plt.hist(no,color="b",edgecolor="r",histtype="step")
plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("no")
plt.show()

# %%
no=[51,21,24,35,37,14,47,22,57,52,36,36,55,48,19,57,18,27,40,24,30,14,51,55
 ,37,23,50,33,36,14,38,59,33,53,38,34,21,56,59,43,36,22,36,38,43,19,34,56,
 17,34]

l=[10,20,30,40,50,60]
plt.hist(no,color="b",edgecolor="r",histtype="bar")
plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("no")
plt.show()

# %%
no=[51,21,24,35,37,14,47,22,57,52,36,36,55,48,19,57,18,27,40,24,30,14,51,55
 ,37,23,50,33,36,14,38,59,33,53,38,34,21,56,59,43,36,22,36,38,43,19,34,56,
 17,34]

l=[10,20,30,40,50,60]
plt.hist(no,color="b",edgecolor="r",orientation="horizontal")
plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("no")
plt.show()

# %%
no=[51,21,24,35,37,14,47,22,57,52,36,36,55,48,19,57,18,27,40,24,30,14,51,55
 ,37,23,50,33,36,14,38,59,33,53,38,34,21,56,59,43,36,22,36,38,43,19,34,56,
 17,34]

l=[10,20,30,40,50,60]
plt.hist(no,color="b",bins=l,edgecolor="r")
plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("no")
plt.show()

# %%
no=[51,21,24,35,37,14,47,22,57,52,36,36,55,48,19,57,18,27,40,24,30,14,51,55
 ,37,23,50,33,36,14,38,59,33,53,38,34,21,56,59,43,36,22,36,38,43,19,34,56,
 17,34]

l=[10,20,30,40,50,60]
plt.hist(no,color="b",edgecolor="r",rwidth=0.8)
plt.title("Histogram")
plt.xlabel("Python")
plt.show()

# %%
no=[51,21,24,35,37,14,47,22,57,52,36,36,55,48,19,57,18,27,40,24,30,14,51,55
 ,37,23,50,33,36,14,38,59,33,53,38,34,21,56,59,43,36,22,36,38,43,19,34,56,
 17,34]

l=[10,20,30,40,50,60]
plt.hist(no,color="b",edgecolor="r",log=True)
plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("no")
plt.show()

# %%
no=[51,21,24,35,37,14,47,22,57,52,36,36,55,48,19,57,18,27,40,24,30,14,51,55
 ,37,23,50,33,36,14,38,59,33,53,38,34,21,56,59,43,36,22,36,38,43,19,34,56,
 17,34]

l=[10,20,30,40,50,60]
plt.hist(no,color="b",edgecolor="r",label="python")
plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("no")
plt.legend()
plt.show()

# %%
no=[51,21,24,35,37,14,47,22,57,52,36,36,55,48,19,57,18,27,40,24,30,14,51,55
 ,37,23,50,33,36,14,38,59,33,53,38,34,21,56,59,43,36,22,36,38,43,19,34,56,
 17,34]

l=[10,20,30,40,50,60]
plt.hist(no,color="b",edgecolor="r")
plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("no")

plt.axvline(45,color="r")
plt.show()

# %%
no=[51,21,24,35,37,14,47,22,57,52,36,36,55,48,19,57,18,27,40,24,30,14,51,55
 ,37,23,50,33,36,14,38,59,33,53,38,34,21,56,59,43,36,22,36,38,43,19,34,56,
 17,34]

l=[10,20,30,40,50,60]
plt.hist(no,color="b",bins=l,edgecolor="r")
plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("no")
plt.grid()
plt.show()
